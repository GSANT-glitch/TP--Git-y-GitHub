# %% [markdown]
# # TP01\-Deeonote Santiago Guillermo

# %% [markdown]
# ¿quién sos?, Mi nombre es Guillermo Santiago

# %% [markdown]
# ¿qué haces?, soy Service manager en la empresa Telefonica\-Movistar, y trabajo analizando clientes y datos\.

# %% [markdown]
# ¿qué expectativas tenés de la materia?, poder incorporar habilidades , para hacer analisis y entender el funcionamiento de la IA, me genera mucha curiosidad

# %%
print("Este es mi primer Deepnote")
# Out:
# Este es mi primer Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=53284fc1-cef4-43eb-bc0d-2de0fcd22ce3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
